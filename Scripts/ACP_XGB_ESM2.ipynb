# %%
import os
# Set working directory
os.chdir("D:/ACP")  # Windows path fix: use forward slash or raw string

print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: D:\ACP

# %%
import pandas as pd
import joblib
import numpy as np
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, auc
)
import matplotlib.pyplot as plt

# %%
# Step 1: Load the datasets (datasets were already splited and saved as csv files, 80,20 split)
train_data = pd.read_csv("acp_train_esm2_features.csv") #train data
test_data = pd.read_csv("acp_test_esm2_features.csv") #test data
# Step 2: Separate labels and features
y_train, X_train = train_data.iloc[:, 2], train_data.iloc[:, 3:] # third column: Label, # from fourth column onward: features
y_test, X_test = test_data.iloc[:, 2], test_data.iloc[:, 3:]

# %%
# Step 3: Define the XGBoost model and hyperparameter grid
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=42) #Random state for reproducibility, logloss for binary classification

param_grid = {
    'n_estimators': [100, 200, 400, 600, 800, 1000], #Number of boosting rounds:Range: 100-1000, Default: 100
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10], #Maximum tree depth:Range: 3-10, Default: 6
    'learning_rate': [0.01, 0.1, 0.2, 0.3], #Step size shrinkage used to prevent ovexgbitting:Range: 0.01-0.3, Default: 0.3
    'subsample': [0.6, 0.8, 1.0], #Fraction of samples used for training trees, Range: 0.5-1.0, Default: 1
    'min_child_weight': [1], #Minimum sum of instance weight (hessian) needed in a child, Range: 1-10, Default: 1
}

# Step 4: Apply GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid, #param_grid is defined above
    scoring='accuracy', #scoring is set to 'accuracy'
    n_jobs= 1, #number of jobs to run in parallel, reasonable value is -1
    cv=5,
    verbose=2 #verbose means how much information to print, 2 means print everything
)
grid_search.fit(X_train, y_train)

# Step 5: Print the Best Hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Step 6: Use the best model from GridSearchCV
best_xgb_model = grid_search.best_estimator_

# Save best hyperparameters to a file
with open('best_model_info_xgb_esm2.txt', 'w') as f:
    f.write("Best Hyperparameters:\n")
    for param, value in grid_search.best_params_.items():
        f.write(f"{param}: {value}\n")

print("Best model information has been saved to 'best_model_info_xgb_esm2.txt'")

#save best model to a file
joblib.dump(best_xgb_model, "best_xgb_esm2_model.pkl")
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   5.4s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   5.4s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  10.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  10.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  10.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  11.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  10.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  15.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  15.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  16.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  16.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  15.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  16.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  16.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  16.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  16.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  15.4s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  15.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  20.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  20.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  19.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  20.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  19.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  21.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  20.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  19.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  20.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  21.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  26.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  25.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  25.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  26.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  30.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  28.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  27.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  27.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  26.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  25.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  26.4s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  26.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  27.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  28.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  28.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   8.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   8.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   8.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   8.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   8.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  16.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  16.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  17.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  17.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  16.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  16.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  16.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  16.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  15.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  24.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  24.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  24.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  25.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  26.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  28.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  28.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  29.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  28.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  28.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  28.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  27.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  27.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  26.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  26.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  34.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  34.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  33.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  34.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  37.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  35.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  35.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  35.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  34.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  34.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  36.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  36.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  38.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  35.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  35.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  43.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  40.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  40.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  38.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  39.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  42.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  42.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  46.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  54.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  57.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  46.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  41.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  40.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  40.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  41.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   6.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   7.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   6.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   6.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  12.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  12.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  11.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  11.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  11.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  12.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  21.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  21.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  21.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  22.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  21.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  23.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  22.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  23.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  23.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  23.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  23.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  24.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  23.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  24.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  23.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  32.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  30.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  34.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  35.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  35.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  35.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  34.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  36.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  36.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  37.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  38.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  35.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  35.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  36.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  37.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  44.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  43.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  44.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  45.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  45.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  43.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  42.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  41.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  43.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  45.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  47.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  46.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  45.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  49.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  46.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  51.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  52.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  47.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  48.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  48.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  50.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  51.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  51.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  51.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  51.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  54.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  53.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  53.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  54.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  51.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   7.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   7.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   9.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   8.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   9.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   8.7s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  13.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  14.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  15.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  15.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  16.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  15.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  14.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  17.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  17.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  16.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  17.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  17.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  25.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  27.7s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  25.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  27.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  25.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  31.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  27.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  31.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  27.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  31.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  30.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  31.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  28.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  31.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  28.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  36.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  39.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  39.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  46.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  38.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  43.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  43.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  47.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  49.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  45.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  46.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  43.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  42.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  48.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  49.1s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  51.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  53.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  54.7s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  58.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  53.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  58.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  58.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  54.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  53.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  54.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  58.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  54.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  57.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  58.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  55.8s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.6; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  54.6s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  55.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  56.9s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  57.0s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=0.8; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 1.2min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 1.2min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 1.2min
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   9.0s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   9.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=  10.9s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=  10.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=1.0; total time=  11.7s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=1.0; total time=  11.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=1.0; total time=  10.9s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=1.0; total time=  10.3s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=1.0; total time=  10.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  17.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  17.1s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  17.8s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  17.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  18.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  18.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  20.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  18.8s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  18.1s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  22.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  20.3s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  19.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  21.0s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  28.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  33.7s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  33.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  33.9s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  35.0s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  38.1s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  36.0s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  34.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  41.7s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  42.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  43.3s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  44.7s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  43.9s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  42.9s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  37.0s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  43.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  42.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  43.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  46.3s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  47.5s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  48.2s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  47.8s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  48.0s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  49.2s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  51.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  49.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  49.6s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  48.4s
# [CV] END learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  50.8s
# ...
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.3s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.8s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.4s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   7.9s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.4s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.5s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.0s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   9.2s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   8.8s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   8.7s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   9.3s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   8.9s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.5s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.3s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.6s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.6s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.7s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.7s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.7s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.7s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.5s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.6s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.8s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.2s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.4s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.0s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  12.0s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  11.6s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  11.6s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  12.3s
# [CV] END learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  11.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   4.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   4.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   5.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   6.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   6.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   6.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   7.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   6.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   9.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   8.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   8.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   9.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   9.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.6; total time=   9.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=0.8; total time=   9.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  10.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  10.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  10.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  11.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  11.0s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  12.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  11.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  11.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  12.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  11.9s
# Best Hyperparameters: {'learning_rate': 0.3, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 800, 'subsample': 0.8}
# Best model information has been saved to 'best_model_info_xgb_esm2.txt'
# ['best_xgb_esm2_model.pkl']

# %%
# Step 8: Fit the model on the training data
best_xgb_model.fit(X_train, y_train)

# Evaluate on the test dataset
y_test_pred = best_xgb_model.predict(X_test)
y_test_prob = best_xgb_model.predict_proba(X_test)[:, 1]

# Calculate and print accuracy, classification reports, and confusion matrices
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"xgb Test Accuracy: {test_accuracy * 100:.2f}%")

# Confusion Matrices
confusion_matrix_test = confusion_matrix(y_test, y_test_pred)
print("Confusion Matrix (Test Data):\n", confusion_matrix_test)

# Sensitivity and Specificity calculation
def calculate_sensitivity_specificity(conf_matrix):
    tn, fp, fn, tp = conf_matrix.ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sensitivity_test, specificity_test = calculate_sensitivity_specificity(confusion_matrix_test)
print("Test Data - Sensitivity:", sensitivity_test, "Specificity:", specificity_test)
# Out:
# xgb Test Accuracy: 82.16%
# Confusion Matrix (Test Data):
#  [[74 17]
#  [16 78]]
# Test Data - Sensitivity: 0.8297872340425532 Specificity: 0.8131868131868132

# %%
print("Confusion Matrix (Test Data):")
print(f"TN: {confusion_matrix_test[0,0]}  FP: {confusion_matrix_test[0,1]}")
print(f"FN: {confusion_matrix_test[1,0]}  TP: {confusion_matrix_test[1,1]}")
# Out:
# Confusion Matrix (Test Data):
# TN: 74  FP: 17
# FN: 16  TP: 78

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, matthews_corrcoef
# Compute metrics
precision = precision_score(y_test, y_test_pred)
mcc = matthews_corrcoef(y_test, y_test_pred)
f1_test = f1_score(y_test, y_test_pred)

# Print the results
print("Precision:", precision)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("F1 Score (Test Data):", f1_test)
# Out:
# Precision: 0.8210526315789474
# Matthews Correlation Coefficient (MCC): 0.6431244329283541
# F1 Score (Test Data): 0.8253968253968254

# %%
#calculation of classification report for test and evaluation data
print("Classification Report (Test Data):\n", classification_report(y_test, y_test_pred))
# Out:
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82        91
#            1       0.82      0.83      0.83        94
#
#     accuracy                           0.82       185
#    macro avg       0.82      0.82      0.82       185
# weighted avg       0.82      0.82      0.82       185

# %%
# Evaluate on the test dataset
y_test_pred = best_xgb_model.predict(X_test)
y_test_prob = best_xgb_model.predict_proba(X_test)[:, 1]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate ROC for test dataset
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_test_prob)
roc_auc_test = auc(fpr_test, tpr_test)

# Print the values
print("Test Data ROC AUC:", roc_auc_test)
print("Test Data FPR:", fpr_test)
print("Test Data TPR:", tpr_test)
print("Test Data Thresholds:", thresholds_test)

# Create a plot
fig, ax = plt.subplots(figsize=(6, 6))  # This defines 'ax' properly

# Plot ROC curve
ax.plot(fpr_test, tpr_test, label=f"ROC AUC = {roc_auc_test:.2f}", color="blue")
ax.plot([0, 1], [0, 1], 'k--', label="Random Classifier (AUC = 0.50)")
ax.set_title("Test Data - ROC Curve")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.legend(loc="lower right")

# Adjust layout and save figure
plt.tight_layout()
plt.savefig("xgb_esm2_roc_auc_curve.png", dpi=500)
print("ROC curve saved as 'xgb_esm2_roc_auc_curve.png'.")

# Show the plot
plt.show()
# Out:
# Test Data ROC AUC: 0.8798223053542202
# Test Data FPR: [0.         0.         0.         0.01098901 0.01098901 0.02197802
#  0.02197802 0.03296703 0.03296703 0.04395604 0.04395604 0.05494505
#  0.05494505 0.06593407 0.06593407 0.07692308 0.07692308 0.08791209
#  0.08791209 0.0989011  0.0989011  0.10989011 0.10989011 0.12087912
#  0.12087912 0.13186813 0.13186813 0.14285714 0.14285714 0.15384615
#  0.15384615 0.16483516 0.16483516 0.18681319 0.18681319 0.1978022
#  0.1978022  0.21978022 0.21978022 0.25274725 0.25274725 0.26373626
#  0.26373626 0.34065934 0.34065934 0.35164835 0.35164835 0.36263736
#  0.36263736 0.46153846 0.46153846 0.52747253 0.52747253 0.8021978
#  0.8021978  1.        ]
# Test Data TPR: [0.         0.0106383  0.17021277 0.17021277 0.27659574 0.27659574
#  0.30851064 0.30851064 0.36170213 0.36170213 0.37234043 0.37234043
#  0.38297872 0.38297872 0.4893617  0.4893617  0.5106383  0.5106383
#  0.5212766  0.5212766  0.53191489 0.53191489 0.54255319 0.54255319
#  0.56382979 0.56382979 0.60638298 0.60638298 0.61702128 0.61702128
#  0.77659574 0.77659574 0.82978723 0.82978723 0.84042553 0.84042553
#  0.86170213 0.86170213 0.87234043 0.87234043 0.89361702 0.89361702
#  0.90425532 0.90425532 0.91489362 0.91489362 0.92553191 0.92553191
#  0.94680851 0.94680851 0.9787234  0.9787234  0.9893617  0.9893617
#  1.         1.        ]
# Test Data Thresholds: [          inf 9.9996781e-01 9.9959999e-01 9.9949121e-01 9.9819416e-01
#  9.9811375e-01 9.9789715e-01 9.9775994e-01 9.9737358e-01 9.9703884e-01
#  9.9632841e-01 9.9628311e-01 9.9620467e-01 9.9591631e-01 9.9242318e-01
#  9.9030882e-01 9.8911822e-01 9.8751825e-01 9.8397452e-01 9.8393792e-01
#  9.8198742e-01 9.7312582e-01 9.7205997e-01 9.7141987e-01 9.6821243e-01
#  9.6060127e-01 9.3171006e-01 9.2790353e-01 9.2185491e-01 9.2089963e-01
#  7.1655345e-01 6.9997895e-01 5.5177587e-01 5.0453103e-01 4.2719626e-01
#  4.0871209e-01 3.2653680e-01 3.0988774e-01 2.9953039e-01 2.4004610e-01
#  1.7256445e-01 1.4588439e-01 1.1578681e-01 4.8862189e-02 3.6967885e-02
#  3.6499996e-02 3.6327638e-02 3.2559693e-02 2.4583438e-02 1.1129904e-02
#  7.6211989e-03 4.8749456e-03 4.6051219e-03 9.0238045e-04 8.8422588e-04
#  2.6132235e-05]
# ROC curve saved as 'xgb_esm2_roc_auc_curve.png'.

# %%
# Perform 10-fold cross-validation on the best model
cross_val_scores = cross_val_score(best_xgb_model, X_train, y_train, cv=10, scoring='accuracy')
print("10-Fold Cross-Validation Accuracy Scores:", cross_val_scores)
print("Mean 10-Fold CV Accuracy:", cross_val_scores.mean())

# save accuracy of each fold to a text file
with open('cv_accuracies_xgb_esm2.txt', 'w') as f:
    f.write("Cross-Validation Accuracies for each fold:\n")
    for i, score in enumerate(cross_val_scores):
        f.write(f"Fold {i+1} Accuracy: {score:.4f}\n")

print("Accuracy of each fold has been saved to 'cv_accuracies_xgb_esm2.txt'")
# Out:
# 10-Fold Cross-Validation Accuracy Scores: [0.75675676 0.83783784 0.68918919 0.78378378 0.82432432 0.81081081
#  0.86486486 0.72972973 0.80821918 0.87671233]
# Mean 10-Fold CV Accuracy: 0.7982228804146613
# Accuracy of each fold has been saved to 'cv_accuracies_xgb_esm2.txt'

# %%
# make roc curve of all folds with mean auc and mean accuracy printed on the plot
mean_accuracy = cross_val_scores.mean() * 100
print(f"Mean Accuracy: {mean_accuracy:.2f}")
# Step 6: Generate ROC Curve
mean_auc = roc_auc_score(y_train, best_xgb_model.predict_proba(X_train)[:, 1])
print(f"Mean AUC: {mean_auc:.4f}")

cv = StratifiedKFold(n_splits=10)
tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)
for i, (train_idx, test_idx) in enumerate(cv.split(X_train, y_train)):
    best_xgb_model.fit(X_train.iloc[train_idx], y_train.iloc[train_idx])
    y_prob = best_xgb_model.predict_proba(X_train.iloc[test_idx])[:, 1]
    fpr, tpr, _ = roc_curve(y_train.iloc[test_idx], y_prob)
    tprs.append(np.interp(mean_fpr, fpr, tpr))
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)
    plt.plot(fpr, tpr, lw=1, alpha=0.3, label=f'Fold {i+1} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
mean_tpr = np.mean(tprs, axis=0)
mean_auc = auc(mean_fpr, mean_tpr)
plt.plot(mean_fpr, mean_tpr, label=f'Mean ROC (AUC = {mean_auc:.2f})', lw=2)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.savefig("cv_roc_curve_xgb_esm2.png", dpi=500)
plt.show()
# Out:
# Mean Accuracy: 79.82
# Mean AUC: 1.0000
