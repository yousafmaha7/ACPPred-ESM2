# %%
import os
# Set working directory
os.chdir("D:/ACP")  # Windows path fix: use forward slash or raw string

print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: D:\ACP

# %%
import numpy as np
import pandas as pd
import joblib
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, auc
)
import matplotlib.pyplot as plt

# %%
# Step 1: Load the datasets (datasets were already splited and saved as csv files, 80,20 split)
train_data = pd.read_csv("acp_train_esm2_features.csv") #train data
test_data = pd.read_csv("acp_test_esm2_features.csv") #test data
# Step 2: Separate labels and features
y_train, X_train = train_data.iloc[:, 2], train_data.iloc[:, 3:] # third column: Label, # from fourth column onward: features
y_test, X_test = test_data.iloc[:, 2], test_data.iloc[:, 3:]

# %%
# Define the AdaBoost model and hyperparameter grid
base_estimator = DecisionTreeClassifier(max_depth=1, random_state=42)
adaboost_model = AdaBoostClassifier(estimator=base_estimator, random_state=42) #base_estimator=base_estimator means use the DecisionTreeClassifier as the base estimator

param_grid = {
    'n_estimators': [50, 200, 400, 500, 600, 800, 1000],               # Number of weak learners, default is 50, range is 10 to 1000
    'learning_rate': [0.01, 0.1, 1.0],            # Controls contribution of each weak learner, default is 1.0, range is 0.01 to 1.0
    'algorithm': ['SAMME'],            # Adaptive boosting algorithm, default is SAMME.R, range is SAMME and SAMME.R; SAMME is equivalent to AdaBoost, SAMME.R is generally faster and often performs better for classification tasks.
    'estimator__max_depth': [1, 3, 5, 7, 9],       # Depth of the decision tree base estimator, default is 1, range is 1 to 10
    'estimator__max_features': ['sqrt', 'log2'], # Number of features to consider when looking for the best split
}
# GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(
    estimator=adaboost_model,
    param_grid=param_grid,
    scoring='accuracy',
    n_jobs=1,
    cv=5,
    verbose=2,
)
grid_search.fit(X_train, y_train)

# Best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Save best hyperparameters to a file
with open('best_model_info_adaboost_esm2.txt', 'w') as f:
    f.write("Best Hyperparameters:\n")
    for param, value in grid_search.best_params_.items():
        f.write(f"{param}: {value}\n")

print("Best model information has been saved to 'best_model_info_adaboost_esm2.txt'")
# Out:
# Fitting 5 folds for each of 210 candidates, totalling 1050 fits
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   1.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   1.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   1.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   1.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   3.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   3.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   3.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   5.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   5.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   5.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   6.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=   7.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=   7.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=   7.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=   7.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=   7.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   1.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   1.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   2.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   2.8s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   2.8s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   2.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   2.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   3.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   3.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   3.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   3.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   4.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   4.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   5.8s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   5.8s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   5.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   5.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=   7.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=   6.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=   7.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=   7.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=   6.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   2.8s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   2.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   3.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   3.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   3.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   3.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   4.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   5.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=   6.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=   6.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=   6.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   1.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   2.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   2.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   5.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   5.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   2.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   2.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   2.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   2.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   2.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   3.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   3.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   3.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   3.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   4.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   1.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   1.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   0.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   1.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   2.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   1.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   2.4s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   2.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   2.9s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   2.7s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   2.6s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   3.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   3.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   3.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   4.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   4.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   5.0s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   5.2s
# [CV] END algorithm=SAMME, estimator__max_depth=1, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   5.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   2.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   2.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=400; total time=   4.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   5.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=500; total time=   5.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   6.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   7.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=600; total time=   6.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   9.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   9.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=800; total time=   9.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=  11.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=  11.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=  11.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=  11.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.01, n_estimators=1000; total time=  11.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=200; total time=   2.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   4.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=400; total time=   4.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   5.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   5.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   5.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   5.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=500; total time=   5.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   6.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   7.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   6.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=600; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   9.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=800; total time=   9.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=  11.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=  11.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=  11.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=  11.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=0.1, n_estimators=1000; total time=  11.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   2.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   2.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=200; total time=   2.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=400; total time=   4.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   5.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   5.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   5.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=500; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   7.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   6.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=600; total time=   6.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   9.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   9.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   9.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=   9.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  11.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  11.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  11.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  11.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  11.6s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   2.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   3.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   3.3s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   3.1s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   3.8s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.7s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.9s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   6.2s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   6.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   6.4s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   6.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   7.5s
# [CV] END algorithm=SAMME, estimator__max_depth=3, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.2s
# ...
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=  16.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=  16.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=  16.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=  16.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=800; total time=  16.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  20.9s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  21.1s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  21.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  21.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=sqrt, learning_rate=1.0, n_estimators=1000; total time=  22.2s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.9s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.9s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.9s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=200; total time=   1.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   4.0s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   1.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   3.9s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   3.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=400; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   1.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=500; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   5.1s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   1.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   5.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=600; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   4.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   1.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   7.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   7.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=800; total time=   6.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   4.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   1.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   8.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   8.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.01, n_estimators=1000; total time=   6.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=200; total time=   1.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=400; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   4.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   4.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   4.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=500; total time=   4.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   5.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   5.2s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   5.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=600; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   7.0s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   7.1s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   7.1s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   7.1s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=800; total time=   7.1s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   8.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   8.9s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=0.1, n_estimators=1000; total time=   9.0s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=50; total time=   0.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   1.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   1.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   1.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   1.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=200; total time=   1.8s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   3.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   3.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   3.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   3.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=400; total time=   3.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   4.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   4.9s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   4.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   4.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=500; total time=   4.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   5.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   5.6s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=600; total time=   5.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   7.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   7.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   7.4s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   7.7s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=800; total time=   7.5s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   9.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   9.2s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   9.2s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   9.3s
# [CV] END algorithm=SAMME, estimator__max_depth=9, estimator__max_features=log2, learning_rate=1.0, n_estimators=1000; total time=   9.4s
# Best Hyperparameters: {'algorithm': 'SAMME', 'estimator__max_depth': 3, 'estimator__max_features': 'sqrt', 'learning_rate': 1.0, 'n_estimators': 800}
# Best model information has been saved to 'best_model_info_adaboost_esm2.txt'

# %%
# Step 6: Use the best model from GridSearchCV
best_adaboost_model = grid_search.best_estimator_

#save best model to a file
joblib.dump(best_adaboost_model, "best_adaboost_esm2_model.pkl")
# Out:
# ['best_adaboost_esm2_model.pkl']

# %%
# Step 8: Fit the model on the training data
best_adaboost_model.fit(X_train, y_train)

# Evaluate on the test dataset
y_test_pred = best_adaboost_model.predict(X_test)
y_test_prob = best_adaboost_model.predict_proba(X_test)[:, 1]

# Calculate and print accuracy, classification reports, and confusion matrices
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"adaboost Test Accuracy: {test_accuracy * 100:.2f}%")

# Confusion Matrices
confusion_matrix_test = confusion_matrix(y_test, y_test_pred)
print("Confusion Matrix (Test Data):\n", confusion_matrix_test)

# Sensitivity and Specificity calculation
def calculate_sensitivity_specificity(conf_matrix):
    tn, fp, fn, tp = conf_matrix.ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sensitivity_test, specificity_test = calculate_sensitivity_specificity(confusion_matrix_test)
print("Test Data - Sensitivity:", sensitivity_test, "Specificity:", specificity_test)
# Out:
# adaboost Test Accuracy: 82.70%
# Confusion Matrix (Test Data):
#  [[75 16]
#  [16 78]]
# Test Data - Sensitivity: 0.8297872340425532 Specificity: 0.8241758241758241

# %%
print("Confusion Matrix (Test Data):")
print(f"TN: {confusion_matrix_test[0,0]}  FP: {confusion_matrix_test[0,1]}")
print(f"FN: {confusion_matrix_test[1,0]}  TP: {confusion_matrix_test[1,1]}")
# Out:
# Confusion Matrix (Test Data):
# TN: 75  FP: 16
# FN: 16  TP: 78

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, matthews_corrcoef
# Compute metrics
precision = precision_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
mcc = matthews_corrcoef(y_test, y_test_pred)

# Print the results
print("Precision:", precision)
print("F1 Score:", f1)
print("Matthews Correlation Coefficient (MCC):", mcc)
# Out:
# Precision: 0.8297872340425532
# F1 Score: 0.8297872340425532
# Matthews Correlation Coefficient (MCC): 0.6539630582183774

# %%
# Evaluate on the test dataset
y_test_pred = best_adaboost_model.predict(X_test)
y_test_prob = best_adaboost_model.predict_proba(X_test)[:, 1]

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate ROC for test dataset
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_test_prob)
roc_auc_test = auc(fpr_test, tpr_test)

# Print the values
print("Test Data ROC AUC:", roc_auc_test)
print("Test Data FPR:", fpr_test)
print("Test Data TPR:", tpr_test)
print("Test Data Thresholds:", thresholds_test)

# Create a plot
fig, ax = plt.subplots(figsize=(6, 6))  # This defines 'ax' properly

# Plot ROC curve
ax.plot(fpr_test, tpr_test, label=f"ROC AUC = {roc_auc_test:.2f}", color="blue")
ax.plot([0, 1], [0, 1], 'k--', label="Random Classifier (AUC = 0.50)")
ax.set_title("Test Data - ROC Curve")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.legend(loc="lower right")

# Adjust layout and save figure
plt.tight_layout()
plt.savefig("adaboost_esm2_roc_auc_curve.png", dpi=500)
print("ROC curve saved as 'adaboost_esm2_roc_auc_curve.png'.")

# Show the plot
plt.show()
# Out:
# Test Data ROC AUC: 0.8942015431377133
# Test Data FPR: [0.         0.         0.         0.01098901 0.01098901 0.02197802
#  0.02197802 0.04395604 0.04395604 0.05494505 0.05494505 0.07692308
#  0.07692308 0.08791209 0.08791209 0.12087912 0.12087912 0.13186813
#  0.13186813 0.14285714 0.14285714 0.15384615 0.15384615 0.16483516
#  0.16483516 0.17582418 0.17582418 0.1978022  0.1978022  0.23076923
#  0.23076923 0.25274725 0.25274725 0.26373626 0.26373626 0.27472527
#  0.27472527 0.34065934 0.34065934 0.46153846 0.46153846 0.52747253
#  0.52747253 0.59340659 0.59340659 0.62637363 0.62637363 1.        ]
# Test Data TPR: [0.         0.0106383  0.27659574 0.27659574 0.32978723 0.32978723
#  0.36170213 0.36170213 0.40425532 0.40425532 0.54255319 0.54255319
#  0.58510638 0.58510638 0.59574468 0.59574468 0.62765957 0.62765957
#  0.65957447 0.65957447 0.67021277 0.67021277 0.76595745 0.76595745
#  0.81914894 0.81914894 0.86170213 0.86170213 0.87234043 0.87234043
#  0.88297872 0.88297872 0.89361702 0.89361702 0.90425532 0.90425532
#  0.92553191 0.92553191 0.95744681 0.95744681 0.96808511 0.96808511
#  0.9787234  0.9787234  0.9893617  0.9893617  1.         1.        ]
# Test Data Thresholds: [       inf 0.63726806 0.5891445  0.589001   0.58511134 0.58480061
#  0.583387   0.57872386 0.57546434 0.5736715  0.55549547 0.55499379
#  0.54563863 0.54398566 0.54258559 0.5411209  0.53877888 0.53687982
#  0.53061484 0.53017931 0.52567202 0.52393738 0.51544459 0.51438318
#  0.50674671 0.50615214 0.49433618 0.48680195 0.4863153  0.48109595
#  0.47966391 0.47797396 0.47736207 0.4767854  0.47633327 0.46689361
#  0.46554246 0.46220095 0.45898736 0.4396935  0.43888098 0.43048512
#  0.42651614 0.42281198 0.42218759 0.42062279 0.42004108 0.35716676]
# ROC curve saved as 'adaboost_esm2_roc_auc_curve.png'.

# %%
# Perform 10-fold cross-validation on the best model
cross_val_scores = cross_val_score(best_adaboost_model, X_train, y_train, cv=10, scoring='accuracy')
print("10-Fold Cross-Validation Accuracy Scores:", cross_val_scores)
print("Mean 10-Fold CV Accuracy:", cross_val_scores.mean())

# save accuracy of each fold to a text file
with open('cv_accuracies_adaboost_esm2.txt', 'w') as f:
    f.write("Cross-Validation Accuracies for each fold:\n")
    for i, score in enumerate(cross_val_scores):
        f.write(f"Fold {i+1} Accuracy: {score:.4f}\n")

print("Accuracy of each fold has been saved to 'cv_accuracies_adaboost_esm2.txt'")
# Out:
# 10-Fold Cross-Validation Accuracy Scores: [0.74324324 0.85135135 0.74324324 0.82432432 0.83783784 0.78378378
#  0.89189189 0.72972973 0.80821918 0.87671233]
# Mean 10-Fold CV Accuracy: 0.8090336912254721
# Accuracy of each fold has been saved to 'cv_accuracies_adaboost_esm2.txt'

# %%
# make roc curve of all folds with mean auc and mean accuracy printed on the plot
mean_accuracy = cross_val_scores.mean() * 100
print(f"Mean Accuracy: {mean_accuracy:.2f}")
# Step 6: Generate ROC Curve
mean_auc = roc_auc_score(y_train, best_adaboost_model.predict_proba(X_train)[:, 1])
print(f"Mean AUC: {mean_auc:.4f}")

cv = StratifiedKFold(n_splits=10)
tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)
for i, (train_idx, test_idx) in enumerate(cv.split(X_train, y_train)):
    best_adaboost_model.fit(X_train.iloc[train_idx], y_train.iloc[train_idx])
    y_prob = best_adaboost_model.predict_proba(X_train.iloc[test_idx])[:, 1]
    fpr, tpr, _ = roc_curve(y_train.iloc[test_idx], y_prob)
    tprs.append(np.interp(mean_fpr, fpr, tpr))
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)
    plt.plot(fpr, tpr, lw=1, alpha=0.3, label=f'Fold {i+1} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
mean_tpr = np.mean(tprs, axis=0)
mean_auc = auc(mean_fpr, mean_tpr)
plt.plot(mean_fpr, mean_tpr, label=f'Mean ROC (AUC = {mean_auc:.2f})', lw=2)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.savefig("cv_roc_curve_adaboost_esm2.png", dpi=500)
plt.show()
# Out:
# Mean Accuracy: 80.90
# Mean AUC: 1.0000
