# %%
# Step 0: Set working directory (optional)
import os
os.chdir("D:/ACP")  # Adjust path as needed
print("Current Working Directory:", os.getcwd())

# Step 1: Import required libraries
import pandas as pd
import numpy as np
import joblib
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score,
    accuracy_score, roc_curve, auc
)
from sklearn.model_selection import GridSearchCV, StratifiedKFold
import matplotlib.pyplot as plt

# Step 2: Load training and testing datasets
train_data = pd.read_csv("acp_train_bert_features.csv")
test_data = pd.read_csv("acp_test_bert_features.csv")

# Step 3: Extract features and labels
y_train = train_data.iloc[:, 2]
X_train = train_data.iloc[:, 3:]
y_test = test_data.iloc[:, 2]
X_test = test_data.iloc[:, 3:]

# Step 4: Set up hyperparameter grid for KNN
param_grid = {
    'n_neighbors': [3, 5, 7, 9], #odd numbers 1-30
    'weights': ['uniform', 'distance'], #uniform or distance
    'metric': ['minkowski', 'manhattan'], #euclidian , manhattan, minkowski
    'p': [1, 2], # power parameter for minkowski
    'algorithm': ['auto', 'brute'] #auto', 'ball_tree', 'kd_tree', 'brute'
}
# Step 5: Grid Search with Cross-Validation
knn = KNeighborsClassifier()
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(knn, param_grid, cv=cv, scoring='accuracy', n_jobs=1, verbose=2)
grid_search.fit(X_train, y_train)

# Step 6: Get the best model
best_knn_model = grid_search.best_estimator_
print("Best Parameters:", grid_search.best_params_)

# Save best hyperparameters to a file
with open('best_model_info_knn_protbert.txt', 'w') as f:
    f.write("Best Hyperparameters:\n")
    for param, value in grid_search.best_params_.items():
        f.write(f"{param}: {value}\n")

print("Best model information has been saved to 'best_model_info_knn_protbert.txt'")
# Out:
# Current Working Directory: D:\ACP
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# Best Parameters: {'algorithm': 'auto', 'metric': 'minkowski', 'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# Best model information has been saved to 'best_model_info_knn_protbert.txt'

# %%
#save best model to a file
joblib.dump(best_knn_model, "best_knn_protbert_model.pkl")

# Step 8: Fit the model on the training data
best_knn_model.fit(X_train, y_train)

# Evaluate on the test dataset
y_test_pred = best_knn_model.predict(X_test)
y_test_prob = best_knn_model.predict_proba(X_test)[:, 1]

# Calculate and print accuracy, classification reports, and confusion matrices
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"knn Test Accuracy: {test_accuracy * 100:.2f}%")

# Confusion Matrices
confusion_matrix_test = confusion_matrix(y_test, y_test_pred)
print("Confusion Matrix (Test Data):\n", confusion_matrix_test)

# Sensitivity and Specificity calculation
def calculate_sensitivity_specificity(conf_matrix):
    tn, fp, fn, tp = conf_matrix.ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sensitivity_test, specificity_test = calculate_sensitivity_specificity(confusion_matrix_test)
print("Test Data - Sensitivity:", sensitivity_test, "Specificity:", specificity_test)
# Out:
# knn Test Accuracy: 74.59%
# Confusion Matrix (Test Data):
#  [[65 26]
#  [21 73]]
# Test Data - Sensitivity: 0.776595744680851 Specificity: 0.7142857142857143

# %%
print("Confusion Matrix (Test Data):")
print(f"TN: {confusion_matrix_test[0,0]}  FP: {confusion_matrix_test[0,1]}")
print(f"FN: {confusion_matrix_test[1,0]}  TP: {confusion_matrix_test[1,1]}")
from sklearn.metrics import f1_score

# calculation of F1 score
f1_test = f1_score(y_test, y_test_pred)
print("F1 Score (Test Data):", f1_test)

#calculation of classification report for test and evaluation data
print("Classification Report (Test Data):\n", classification_report(y_test, y_test_pred))

# Evaluate on the test dataset
y_test_pred = best_knn_model.predict(X_test)
y_test_prob = best_knn_model.predict_proba(X_test)[:, 1]

from sklearn.metrics import precision_score, recall_score, f1_score, matthews_corrcoef
# Compute metrics
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
mcc = matthews_corrcoef(y_test, y_test_pred)

# Print the results
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Matthews Correlation Coefficient (MCC):", mcc)
# Out:
# Confusion Matrix (Test Data):
# TN: 65  FP: 26
# FN: 21  TP: 73
# F1 Score (Test Data): 0.7564766839378239
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73        91
#            1       0.74      0.78      0.76        94
#
#     accuracy                           0.75       185
#    macro avg       0.75      0.75      0.75       185
# weighted avg       0.75      0.75      0.75       185
#
# Precision: 0.7373737373737373
# Recall: 0.776595744680851
# F1 Score: 0.7564766839378239
# Matthews Correlation Coefficient (MCC): 0.49203322371029345

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate ROC for test dataset
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_test_prob)
roc_auc_test = auc(fpr_test, tpr_test)

# Print the values
print("Test Data ROC AUC:", roc_auc_test)
print("Test Data FPR:", fpr_test)
print("Test Data TPR:", tpr_test)
print("Test Data Thresholds:", thresholds_test)

# Create a plot
fig, ax = plt.subplots(figsize=(6, 6))  # This defines 'ax' properly

# Plot ROC curve
ax.plot(fpr_test, tpr_test, label=f"ROC AUC = {roc_auc_test:.2f}", color="blue")
ax.plot([0, 1], [0, 1], 'k--', label="Random Classifier (AUC = 0.50)")
ax.set_title("Test Data - ROC Curve")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.legend(loc="lower right")

# Adjust layout and save figure
plt.tight_layout()
plt.savefig("knn_protbert_roc_auc_curve.png", dpi=500)
print("ROC curve saved as 'knn_protbert_roc_auc_curve.png'.")

# Show the plot
plt.show()
# Out:
# Test Data ROC AUC: 0.8367430441898527
# Test Data FPR: [0.         0.02197802 0.03296703 0.08791209 0.15384615 0.28571429
#  0.41758242 0.54945055 0.71428571 0.83516484 1.        ]
# Test Data TPR: [0.         0.18085106 0.36170213 0.56382979 0.70212766 0.77659574
#  0.87234043 0.92553191 0.9787234  0.9893617  1.        ]
# Test Data Thresholds: [       inf 1.         0.88888889 0.77777778 0.66666667 0.55555556
#  0.44444444 0.33333333 0.22222222 0.11111111 0.        ]
# ROC curve saved as 'knn_protbert_roc_auc_curve.png'.

# %%
from sklearn.model_selection import cross_val_score
# Perform 10-fold cross-validation on the best model
cross_val_scores = cross_val_score(best_knn_model, X_train, y_train, cv=10, scoring='accuracy')
print("10-Fold Cross-Validation Accuracy Scores:", cross_val_scores)
print("Mean 10-Fold CV Accuracy:", cross_val_scores.mean())

# save accuracy of each fold to a text file
with open('cv_accuracies_knn_protbert.txt', 'w') as f:
    f.write("Cross-Validation Accuracies for each fold:\n")
    for i, score in enumerate(cross_val_scores):
        f.write(f"Fold {i+1} Accuracy: {score:.4f}\n")

print("Accuracy of each fold has been saved to 'cv_accuracies_knn_protbert.txt'")
# Out:
# 10-Fold Cross-Validation Accuracy Scores: [0.72972973 0.78378378 0.74324324 0.7027027  0.75675676 0.75675676
#  0.83783784 0.74324324 0.71232877 0.79452055]
# Mean 10-Fold CV Accuracy: 0.7560903369122547
# Accuracy of each fold has been saved to 'cv_accuracies_knn_protbert.txt'

# %%
# make roc curve of all folds with mean auc and mean accuracy printed on the plot
mean_accuracy = cross_val_scores.mean() * 100
print(f"Mean Accuracy: {mean_accuracy:.2f}")
# Step 6: Generate ROC Curve
mean_auc = roc_auc_score(y_train, best_knn_model.predict_proba(X_train)[:, 1])
print(f"Mean AUC: {mean_auc:.4f}")

cv = StratifiedKFold(n_splits=10)
tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)
for i, (train_idx, test_idx) in enumerate(cv.split(X_train, y_train)):
    best_knn_model.fit(X_train.iloc[train_idx], y_train.iloc[train_idx])
    y_prob = best_knn_model.predict_proba(X_train.iloc[test_idx])[:, 1]
    fpr, tpr, _ = roc_curve(y_train.iloc[test_idx], y_prob)
    tprs.append(np.interp(mean_fpr, fpr, tpr))
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)
    plt.plot(fpr, tpr, lw=1, alpha=0.3, label=f'Fold {i+1} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
mean_tpr = np.mean(tprs, axis=0)
mean_auc = auc(mean_fpr, mean_tpr)
plt.plot(mean_fpr, mean_tpr, label=f'Mean ROC (AUC = {mean_auc:.2f})', lw=2)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.savefig("cv_roc_curve_knn_protbert.png", dpi=500)
plt.show()
# Out:
# Mean Accuracy: 75.61
# Mean AUC: 0.8915
