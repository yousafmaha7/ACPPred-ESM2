# %%
import os
# Set working directory
os.chdir("D:/ACP")  # Windows path fix: use forward slash or raw string

print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: D:\ACP

# %%
import pandas as pd
import joblib
import numpy as np
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, auc
)
import matplotlib.pyplot as plt

# %%
# Step 1: Load the datasets (datasets were already splited and saved as csv files, 80,20 split)
train_data = pd.read_csv("acp_train_bert_features.csv") #train data
test_data = pd.read_csv("acp_test_bert_features.csv") #test data
# Step 2: Separate labels and features
y_train, X_train = train_data.iloc[:, 2], train_data.iloc[:, 3:] # third column: Label, # from fourth column onward: features
y_test, X_test = test_data.iloc[:, 2], test_data.iloc[:, 3:]

# %%
# Step 3: Define the XGBoost model and hyperparameter grid
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=42) #Random state for reproducibility, logloss for binary classification

param_grid = {
    'n_estimators': [100, 200, 400, 600, 800, 1000], #Number of boosting rounds:Range: 100-1000, Default: 100
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10], #Maximum tree depth:Range: 3-10, Default: 6
    'learning_rate': [0.01, 0.1, 0.2, 0.3], #Step size shrinkage used to prevent ovexgbitting:Range: 0.01-0.3, Default: 0.3
    'subsample': [0.6, 0.8, 1.0], #Fraction of samples used for training trees, Range: 0.5-1.0, Default: 1
    'min_child_weight': [1], #Minimum sum of instance weight (hessian) needed in a child, Range: 1-10, Default: 1
}

# Step 4: Apply GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid, #param_grid is defined above
    scoring='accuracy', #scoring is set to 'accuracy'
    n_jobs= 1, #number of jobs to run in parallel, reasonable value is -1
    cv=5,
    verbose=2 #verbose means how much information to print, 2 means print everything
)
grid_search.fit(X_train, y_train)

# Step 5: Print the Best Hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Step 6: Use the best model from GridSearchCV
best_xgb_model = grid_search.best_estimator_

# Save best hyperparameters to a file
with open('best_model_info_xgb_protbert.txt', 'w') as f:
    f.write("Best Hyperparameters:\n")
    for param, value in grid_search.best_params_.items():
        f.write(f"{param}: {value}\n")

print("Best model information has been saved to 'best_model_info_xgb_protbert.txt'")

#save best model to a file
joblib.dump(best_xgb_model, "best_xgb_protbert_model.pkl")
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.4s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.6; total time=   7.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   7.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   7.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   7.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   7.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   7.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  10.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  10.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  10.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  10.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  10.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  13.5s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  13.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  13.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  13.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  13.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  13.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  13.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  16.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  16.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  16.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  17.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  21.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  20.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  20.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  19.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  19.6s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  19.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   6.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   6.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   6.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   7.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, subsample=1.0; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  12.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  12.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  11.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  12.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  11.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  12.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  12.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  11.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  12.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  12.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  17.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  17.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  16.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  16.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  17.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  17.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  17.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  19.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  17.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  17.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  17.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  17.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  18.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  18.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  24.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  24.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  22.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  24.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  26.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  26.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  25.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  25.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  24.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8; total time=  23.8s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  23.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  24.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  24.3s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  25.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0; total time=  25.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  32.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  30.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  31.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  32.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6; total time=  31.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  31.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  31.5s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  32.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  33.4s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  33.6s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  34.9s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  34.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  33.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  33.0s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  32.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  10.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  10.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=  10.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  11.5s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  11.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  12.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  11.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0; total time=  12.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  19.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  19.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  20.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  19.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.6; total time=  19.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  19.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  19.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  18.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  20.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  19.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  20.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  19.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  19.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  22.4s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  29.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  29.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  28.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  30.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.6; total time=  28.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  29.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  27.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  29.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  30.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=0.8; total time=  33.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  30.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  29.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  28.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  29.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=600, subsample=1.0; total time=  29.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  36.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  34.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  34.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=  34.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6; total time=
    tn, fp, fn, tp = conf_matrix.ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sensitivity_test, specificity_test = calculate_sensitivity_specificity(confusion_matrix_test)
print("Test Data - Sensitivity:", sensitivity_test, "Specificity:", specificity_test)
# Out:
# xgb Test Accuracy: 78.38%
# Confusion Matrix (Test Data):
#  [[70 21]
#  [19 75]]
# Test Data - Sensitivity: 0.7978723404255319 Specificity: 0.7692307692307693

# %%
print("Confusion Matrix (Test Data):")
print(f"TN: {confusion_matrix_test[0,0]}  FP: {confusion_matrix_test[0,1]}")
print(f"FN: {confusion_matrix_test[1,0]}  TP: {confusion_matrix_test[1,1]}")
# Out:
# Confusion Matrix (Test Data):
# TN: 70  FP: 21
# FN: 19  TP: 75

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, matthews_corrcoef
# Compute metrics
precision = precision_score(y_test, y_test_pred)
mcc = matthews_corrcoef(y_test, y_test_pred)
f1_test = f1_score(y_test, y_test_pred)

# Print the results
print("Precision:", precision)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("F1 Score (Test Data):", f1_test)
# Out:
# Precision: 0.78125
# Matthews Correlation Coefficient (MCC): 0.5674348847444467
# F1 Score (Test Data): 0.7894736842105263

# %%
#calculation of classification report for test and evaluation data
print("Classification Report (Test Data):\n", classification_report(y_test, y_test_pred))
# Out:
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78        91
#            1       0.78      0.80      0.79        94
#
#     accuracy                           0.78       185
#    macro avg       0.78      0.78      0.78       185
# weighted avg       0.78      0.78      0.78       185

# %%
# Evaluate on the test dataset
y_test_pred = best_xgb_model.predict(X_test)
y_test_prob = best_xgb_model.predict_proba(X_test)[:, 1]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate ROC for test dataset
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_test_prob)
roc_auc_test = auc(fpr_test, tpr_test)

# Print the values
print("Test Data ROC AUC:", roc_auc_test)
print("Test Data FPR:", fpr_test)
print("Test Data TPR:", tpr_test)
print("Test Data Thresholds:", thresholds_test)

# Create a plot
fig, ax = plt.subplots(figsize=(6, 6))  # This defines 'ax' properly

# Plot ROC curve
ax.plot(fpr_test, tpr_test, label=f"ROC AUC = {roc_auc_test:.2f}", color="blue")
ax.plot([0, 1], [0, 1], 'k--', label="Random Classifier (AUC = 0.50)")
ax.set_title("Test Data - ROC Curve")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.legend(loc="lower right")

# Adjust layout and save figure
plt.tight_layout()
plt.savefig("xgb_protbert_roc_auc_curve.png", dpi=500)
print("ROC curve saved as 'xgb_protbert_roc_auc_curve.png'.")

# Show the plot
plt.show()
# Out:
# Test Data ROC AUC: 0.8436988543371522
# Test Data FPR: [0.         0.         0.         0.01098901 0.01098901 0.02197802
#  0.02197802 0.03296703 0.03296703 0.04395604 0.04395604 0.05494505
#  0.05494505 0.07692308 0.07692308 0.08791209 0.08791209 0.10989011
#  0.10989011 0.12087912 0.12087912 0.15384615 0.15384615 0.16483516
#  0.16483516 0.18681319 0.18681319 0.20879121 0.20879121 0.23076923
#  0.23076923 0.24175824 0.24175824 0.25274725 0.25274725 0.26373626
#  0.26373626 0.30769231 0.30769231 0.36263736 0.36263736 0.37362637
#  0.37362637 0.3956044  0.3956044  0.42857143 0.42857143 0.43956044
#  0.43956044 0.48351648 0.48351648 0.53846154 0.53846154 0.68131868
#  0.68131868 0.7032967  0.7032967  0.74725275 0.74725275 0.96703297
#  0.96703297 1.        ]
# Test Data TPR: [0.         0.0106383  0.20212766 0.20212766 0.25531915 0.25531915
#  0.31914894 0.31914894 0.32978723 0.32978723 0.42553191 0.42553191
#  0.43617021 0.43617021 0.45744681 0.45744681 0.5106383  0.5106383
#  0.57446809 0.57446809 0.60638298 0.60638298 0.65957447 0.65957447
#  0.71276596 0.71276596 0.73404255 0.73404255 0.75531915 0.75531915
#  0.79787234 0.79787234 0.80851064 0.80851064 0.82978723 0.82978723
#  0.84042553 0.84042553 0.85106383 0.85106383 0.86170213 0.86170213
#  0.87234043 0.87234043 0.88297872 0.88297872 0.89361702 0.89361702
#  0.91489362 0.91489362 0.92553191 0.92553191 0.94680851 0.94680851
#  0.96808511 0.96808511 0.9787234  0.9787234  0.9893617  0.9893617
#  1.         1.        ]
# Test Data Thresholds: [           inf 9.99935865e-01 9.96222734e-01 9.96091545e-01
#  9.95506644e-01 9.94554996e-01 9.91308033e-01 9.90733862e-01
#  9.88408923e-01 9.85200047e-01 9.76540625e-01 9.75681841e-01
#  9.72086966e-01 9.68173742e-01 9.56093550e-01 9.54744101e-01
#  9.41505849e-01 9.32346344e-01 8.98243189e-01 8.93251121e-01
#  8.85803342e-01 8.69472325e-01 8.27991843e-01 8.17674696e-01
#  7.75052369e-01 7.10437357e-01 6.67397857e-01 6.39384747e-01
#  5.86633325e-01 5.35755217e-01 5.01370609e-01 4.77586269e-01
#  4.69192058e-01 4.43427175e-01 4.20802116e-01 3.85674834e-01
#  3.58881593e-01 2.89199442e-01 2.70629793e-01 2.08440334e-01
#  2.05679759e-01 1.99794576e-01 1.93889812e-01 1.66367441e-01
#  1.52334049e-01 1.20641045e-01 1.09945089e-01 1.06610589e-01
#  9.45999324e-02 4.91468832e-02 4.78532761e-02 3.86026129e-02
#  3.34825665e-02 8.00623558e-03 6.80160196e-03 6.13157684e-03
#  5.63549763e-03 4.43574646e-03 3.07177706e-03 4.48003964e-04
#  3.51039635e-04 4.35201910e-05]
# ROC curve saved as 'xgb_protbert_roc_auc_curve.png'.

# %%
# Perform 10-fold cross-validation on the best model
cross_val_scores = cross_val_score(best_xgb_model, X_train, y_train, cv=10, scoring='accuracy')
print("10-Fold Cross-Validation Accuracy Scores:", cross_val_scores)
print("Mean 10-Fold CV Accuracy:", cross_val_scores.mean())

# save accuracy of each fold to a text file
with open('cv_accuracies_xgb_protbert.txt', 'w') as f:
    f.write("Cross-Validation Accuracies for each fold:\n")
    for i, score in enumerate(cross_val_scores):
        f.write(f"Fold {i+1} Accuracy: {score:.4f}\n")

print("Accuracy of each fold has been saved to 'cv_accuracies_xgb_protbert.txt'")
# Out:
# 10-Fold Cross-Validation Accuracy Scores: [0.71621622 0.85135135 0.74324324 0.72972973 0.7972973  0.75675676
#  0.89189189 0.78378378 0.76712329 0.79452055]
# Mean 10-Fold CV Accuracy: 0.7831914105886708
# Accuracy of each fold has been saved to 'cv_accuracies_xgb_protbert.txt'

# %%
# make roc curve of all folds with mean auc and mean accuracy printed on the plot
mean_accuracy = cross_val_scores.mean() * 100
print(f"Mean Accuracy: {mean_accuracy:.2f}")
# Step 6: Generate ROC Curve
mean_auc = roc_auc_score(y_train, best_xgb_model.predict_proba(X_train)[:, 1])
print(f"Mean AUC: {mean_auc:.4f}")

cv = StratifiedKFold(n_splits=10)
tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)
for i, (train_idx, test_idx) in enumerate(cv.split(X_train, y_train)):
    best_xgb_model.fit(X_train.iloc[train_idx], y_train.iloc[train_idx])
    y_prob = best_xgb_model.predict_proba(X_train.iloc[test_idx])[:, 1]
    fpr, tpr, _ = roc_curve(y_train.iloc[test_idx], y_prob)
    tprs.append(np.interp(mean_fpr, fpr, tpr))
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)
    plt.plot(fpr, tpr, lw=1, alpha=0.3, label=f'Fold {i+1} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
mean_tpr = np.mean(tprs, axis=0)
mean_auc = auc(mean_fpr, mean_tpr)
plt.plot(mean_fpr, mean_tpr, label=f'Mean ROC (AUC = {mean_auc:.2f})', lw=2)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.savefig("cv_roc_curve_xgb_protbert.png", dpi=500)
plt.show()
# Out:
# Mean Accuracy: 78.32
# Mean AUC: 1.0000
